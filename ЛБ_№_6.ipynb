# %% [markdown]
# <a href="https://colab.research.google.com/github/BohdanShepel2005/Numerical-Methods-of-Programming/blob/main/%D0%9B%D0%91_%E2%84%96_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import lagrange

x=np.array([-4, -2, 1, 3], dtype=float)
y=np.array([-8, 10, -8, 20], dtype=float)
x_test = -3 # точка, в якій потрібно обчислити значення (-3, 1, 0.5, 2.5)

def lagrange_interpolation(x, y, x_test):
    n = len(x)
    p = np.zeros(n) # масив для зберігання значень багаточленів L_i
    for i in range(n):
        # обчислюємо багаточлен L_i, який складається з n членів
        # кожен член дорівнює добутку (x-x_j)/(x_i-x_j) для j=0..n, j!=i
        p_i = 1
        for j in range(n):
            if i != j:
                p_i *= (x_test - x[j])/(x[i] - x[j])
        p[i] = p_i
    return np.dot(y, p) # повертаємо значення багаточлена у точці x_test

# обчислюємо інтерполяційний багаточлен та його значення у точці x_test
f_interp = lagrange_interpolation(x, y, x_test)
print("Значення функції у точці x =", x_test,"дорівнює", f_interp.round(4))
x_test = -1
f_interp = lagrange_interpolation(x, y, x_test)
print("Значення функції у точці x =", x_test,"дорівнює", f_interp.round(4))
x_test = 0.5
f_interp = lagrange_interpolation(x, y, x_test)
print("Значення функції у точці x =", x_test,"дорівнює", f_interp.round(4))
x_test = 2.5
f_interp = lagrange_interpolation(x, y, x_test)
print("Значення функції у точці x =", x_test,"дорівнює", f_interp.round(4))
# Out:
# Значення функції у точці x = -3 дорівнює 8.0
# Значення функції у точці x = -1 дорівнює 4.0
# Значення функції у точці x = 0.5 дорівнює -6.875
# Значення функції у точці x = 2.5 дорівнює 6.625

# %%
xnew=np.linspace(np.min(x),np.max(x),100) #точки, за якими будуємо графік
ynew=[lagrange_interpolation(x,y,i) for i in xnew]

# Візуалізація інтерполяції
fig = plt.figure(figsize=(6, 3))
plt.plot(x, y, 'o', xnew, ynew)
plt.title('Lagrange Polynomial_1')
plt.grid(True)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# Перевірка за допомогою функції lagrange з scipy
f = lagrange(x, y)
fig = plt.figure(figsize=(6, 3))
plt.plot(xnew, f(xnew), 'b', x, y, 'ro')
plt.title('Lagrange Polynomial_2')
plt.grid(True)
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')
